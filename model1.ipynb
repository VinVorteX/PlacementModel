# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

plt.scatter(df['cgpa'],df['iq'], c=df['placement'])

# %% [markdown]
# df.shape

# %%
x = df.iloc[:, 0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 35   6.8   90.0
# 7    5.0   63.0
# 99   6.2  113.0
# 19   5.2  132.0
# 3    7.4  132.0
# ..   ...    ...
# 71   6.1  132.0
# 26   7.0  199.0
# 15   5.1  176.0
# 79   6.5   90.0
# 95   4.3  200.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 53   8.3  168.0
# 16   5.2  224.0
# 0    6.8  123.0
# 17   3.3  183.0
# 37   8.1  149.0
# 88   4.4  149.0
# 25   5.0   91.0
# 34   4.8  163.0
# 12   5.4  139.0
# 5    7.1   48.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.73469986, -0.81826197],
#        [-0.93460417, -1.5231101 ],
#        [ 0.17826518, -0.21783578],
#        [-0.74912594,  0.27816846],
#        [ 1.29113453,  0.27816846],
#        [ 0.08552607, -1.05321135],
#        [ 1.94030832,  1.165755  ],
#        [-1.12008239, -0.24394127],
#        [ 0.2710043 ,  0.14764103],
#        [ 1.47661276,  0.17374652],
#        [ 0.2710043 , -0.47889065],
#        [-0.28543038,  0.48701235],
#        [-0.00721304,  0.72196173],
#        [-1.21282151, -0.00899189],
#        [-1.12008239,  0.51311784],
#        [ 0.54922163,  0.43480138],
#        [-1.21282151, -1.81027045],
#        [-1.02734328, -1.57532108],
#        [-0.84186506, -1.44479364],
#        [ 1.38387365,  0.22595749],
#        [-0.65638683, -0.00899189],
#        [ 1.66209098, -0.19173029],
#        [-1.02734328,  1.94891959],
#        [-0.65638683, -0.19173029],
#        [ 1.19839542,  0.40869589],
#        [ 0.92017808, -0.24394127],
#        [-0.84186506,  0.17374652],
#        [-0.00721304, -0.50499613],
#        [-1.86199529, -1.20984427],
#        [ 0.36374341,  0.51311784],
#        [-1.02734328,  0.7741727 ],
#        [ 0.08552607,  0.90470014],
#        [ 0.45648252, -2.20185275],
#        [ 0.82743897, -0.66162905],
#        [ 1.19839542, -0.13951932],
#        [ 2.31126477, -0.03509738],
#        [ 0.64196075,  0.85248916],
#        [-0.00721304, -1.44479364],
#        [ 0.64196075,  1.58344278],
#        [-1.21282151, -0.89657843],
#        [ 0.54922163, -0.03509738],
#        [-0.56364772,  0.35648492],
#        [-1.02734328,  0.33037943],
#        [-0.56364772, -0.19173029],
#        [ 0.92017808,  0.46090687],
#        [-2.32569086,  2.91482259],
#        [-0.74912594,  1.03522757],
#        [-1.02734328, -0.03509738],
#        [ 1.0129172 ,  0.7741727 ],
#        [-0.56364772, -0.3744687 ],
#        [ 1.38387365, -1.57532108],
#        [ 0.08552607, -0.47889065],
#        [ 0.92017808, -1.49700462],
#        [ 0.45648252,  0.22595749],
#        [ 1.19839542, -0.92268391],
#        [-0.09995215, -0.40057419],
#        [-0.74912594, -0.29615224],
#        [-1.02734328,  0.87859465],
#        [ 0.82743897,  0.46090687],
#        [ 0.2710043 ,  0.17374652],
#        [-0.00721304,  0.06932457],
#        [-0.19269127,  0.53922333],
#        [ 0.45648252,  1.00912208],
#        [ 1.38387365,  0.95691111],
#        [-0.28543038,  0.27816846],
#        [ 0.73469986,  0.51311784],
#        [ 0.08552607, -1.47089913],
#        [-0.00721304, -1.99300886],
#        [ 1.47661276, -0.84436746],
#        [-1.95473441, -0.32225773],
#        [ 0.82743897,  0.43480138],
#        [-0.28543038,  0.56532881],
#        [ 0.73469986, -0.24394127],
#        [-0.74912594, -0.81826197],
#        [-1.86199529, -0.5572071 ],
#        [-1.12008239,  1.24407146],
#        [-0.93460417, -0.08730835],
#        [ 0.36374341, -0.13951932],
#        [-0.19269127,  1.165755  ],
#        [-1.30556062,  0.64364527],
#        [-1.49103884, -2.07132532],
#        [-0.28543038,  1.24407146],
#        [ 1.84756921, -1.10542232],
#        [ 0.92017808,  1.40070438],
#        [ 1.19839542, -1.86248143],
#        [ 0.08552607,  0.27816846],
#        [ 0.92017808,  2.02723605],
#        [-0.84186506,  1.42680986],
#        [ 0.45648252, -0.81826197],
#        [-1.58377796,  2.05334154]])

# %%
x_test = scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[ 1.56894902,  0.52531363],
#        [-0.40818186,  1.73591293],
#        [ 0.61227279, -0.44748939],
#        [-1.61997176,  0.8495813 ],
#        [ 1.44139219,  0.11457458],
#        [-0.91840919,  0.11457458],
#        [-0.53573869, -1.13926042],
#        [-0.66329552,  0.4172244 ],
#        [-0.28062503, -0.10160387],
#        [ 0.80360804, -2.06882774]])

# %%
from sklearn.linear_model import LogisticRegression

clt = LogisticRegression()

# %%
clt.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clt.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 1, 0, 1, 0, 0, 0, 0, 1])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
y_test
# Out:
# 53    1
# 16    0
# 0     1
# 17    0
# 37    1
# 88    0
# 25    0
# 34    0
# 12    0
# 5     1
# Name: placement, dtype: int64

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clt,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clt, open('model.pkl', 'wb'))
